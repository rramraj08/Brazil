# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'alldatasets.xlsx',sheet_name='Brazil')

# %%
df.head()
# Out:
#   childid country  height  stunting_2cat  EDUYRS2   z_score  agegapr1  \
# 0     BR1  Brazil  180.35            0.0     16.0  0.399053       0.0
# 1     BR2  Brazil  164.95            0.0     15.0  0.002132       NaN
# 2     BR8  Brazil  167.10            1.0      5.0 -2.061853       6.0
# 3    BR12  Brazil  174.75            0.0     13.0  1.351661       2.0
# 4    BR14  Brazil  179.35            0.0     11.0  0.557821       NaN
#
#    momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  job_cat  pvt_sector  \
# 0          5.0        1      50.0       3.0  0.306352      3.0           1
# 1          5.0        0      52.0       3.0  0.533106      3.0           1
# 2          5.0        1      49.0      12.0  0.115514      3.0           1
# 3          6.0        1      51.0       5.0  0.597647      3.0           1
# 4         10.0        1      50.0       3.0  0.483788      3.0           1
#
#       earn_usd
# 0   290.316010
# 1   109.973544
# 2   109.973544
# 3  1060.838040
# 4   353.612680

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398 entries, 0 to 2397
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   childid        2398 non-null   object
#  1   country        2398 non-null   object
#  2   height         2354 non-null   float64
#  3   stunting_2cat  2140 non-null   float64
#  4   EDUYRS2        2396 non-null   float64
#  5   z_score        2378 non-null   float64
#  6   agegapr1       1784 non-null   float64
#  7   momeduyrsr1    2393 non-null   float64
#  8   chsexr1        2398 non-null   int64
#  9   agemonr1       2143 non-null   float64
#  10  hhsizer1       2192 non-null   float64
#  11  wi_newr1       2187 non-null   float64
#  12  job_cat        2396 non-null   float64
#  13  pvt_sector     2398 non-null   int64
#  14  earn_usd       2398 non-null   float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 281.1+ KB

# %%
import statsmodels.api as sm

# %% [markdown]
# # cognition

# %%
#cognition

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     67.25
# Date:                Sun, 09 May 2021   Prob (F-statistic):           4.10e-16
# Time:                        18:24:24   Log-Likelihood:                -2852.7
# No. Observations:                2120   AIC:                             5709.
# Df Residuals:                    2118   BIC:                             5721.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0124      0.021     -0.582      0.560      -0.054       0.029
# stunting_2cat    -0.5497      0.067     -8.201      0.000      -0.681      -0.418
# ==============================================================================
# Omnibus:                        2.432   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.296   Jarque-Bera (JB):                2.251
# Skew:                          -0.001   Prob(JB):                        0.324
# Kurtosis:                       2.840   Cond. No.                         3.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Height

# %%
#Height

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     199.0
# Date:                Sun, 09 May 2021   Prob (F-statistic):           2.97e-43
# Time:                        18:24:24   Log-Likelihood:                -7523.7
# No. Observations:                2104   AIC:                         1.505e+04
# Df Residuals:                    2102   BIC:                         1.506e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           169.8540      0.199    853.774      0.000     169.464     170.244
# stunting_2cat    -8.8009      0.624    -14.108      0.000     -10.024      -7.578
# ==============================================================================
# Omnibus:                       67.043   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.786
# Skew:                           0.024   Prob(JB):                     1.25e-07
# Kurtosis:                       2.400   Cond. No.                         3.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # education

# %%
#education

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     87.63
# Date:                Sun, 09 May 2021   Prob (F-statistic):           1.93e-20
# Time:                        18:24:24   Log-Likelihood:                -5849.5
# No. Observations:                2138   AIC:                         1.170e+04
# Df Residuals:                    2136   BIC:                         1.171e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            11.0360      0.085    129.433      0.000      10.869      11.203
# stunting_2cat    -2.4882      0.266     -9.361      0.000      -3.010      -1.967
# ==============================================================================
# Omnibus:                       30.818   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.748
# Skew:                          -0.291   Prob(JB):                     1.28e-07
# Kurtosis:                       2.865   Cond. No.                         3.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # cognition covariates

# %%
df.columns
# Out:
# Index(['childid', 'country', 'height', 'stunting_2cat', 'EDUYRS2', 'z_score',
#        'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1', 'hhsizer1',
#        'wi_newr1', 'job_cat', 'pvt_sector', 'earn_usd'],
#       dtype='object')

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.252
# Method:                 Least Squares   F-statistic:                     73.43
# Date:                Sun, 09 May 2021   Prob (F-statistic):           1.71e-91
# Time:                        18:24:25   Log-Likelihood:                -1830.9
# No. Observations:                1506   AIC:                             3678.
# Df Residuals:                    1498   BIC:                             3720.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -1.7137      0.263     -6.505      0.000      -2.230      -1.197
# stunting_2cat    -0.2123      0.075     -2.813      0.005      -0.360      -0.064
# agemonr1          0.0205      0.006      3.565      0.000       0.009       0.032
# chsexr1           0.0759      0.043      1.766      0.078      -0.008       0.160
# agegapr1          0.0012      0.005      0.225      0.822      -0.009       0.012
# momeduyrsr1       0.0663      0.006     10.294      0.000       0.054       0.079
# hhsizer1         -0.0680      0.012     -5.614      0.000      -0.092      -0.044
# wi_newr1          1.3537      0.137      9.877      0.000       1.085       1.623
# ==============================================================================
# Omnibus:                        1.008   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.604   Jarque-Bera (JB):                1.067
# Skew:                          -0.034   Prob(JB):                        0.587
# Kurtosis:                       2.889   Cond. No.                         554.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Height covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     300.0
# Date:                Sun, 09 May 2021   Prob (F-statistic):          4.35e-279
# Time:                        18:24:25   Log-Likelihood:                -4761.9
# No. Observations:                1497   AIC:                             9540.
# Df Residuals:                    1489   BIC:                             9582.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           159.8537      1.883     84.908      0.000     156.161     163.547
# stunting_2cat    -8.6255      0.538    -16.019      0.000      -9.682      -7.569
# agemonr1          0.0167      0.041      0.407      0.684      -0.064       0.097
# chsexr1          12.9281      0.308     41.936      0.000      12.323      13.533
# agegapr1         -0.0513      0.038     -1.352      0.176      -0.126       0.023
# momeduyrsr1       0.1875      0.046      4.076      0.000       0.097       0.278
# hhsizer1          0.1460      0.087      1.682      0.093      -0.024       0.316
# wi_newr1          0.3993      0.983      0.406      0.685      -1.529       2.328
# ==============================================================================
# Omnibus:                        5.143   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.076   Jarque-Bera (JB):                5.037
# Skew:                           0.132   Prob(JB):                       0.0806
# Kurtosis:                       3.105   Cond. No.                         553.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # education covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     96.82
# Date:                Sun, 09 May 2021   Prob (F-statistic):          6.41e-117
# Time:                        18:24:25   Log-Likelihood:                -3894.2
# No. Observations:                1520   AIC:                             7804.
# Df Residuals:                    1512   BIC:                             7847.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             6.9787      1.008      6.924      0.000       5.002       8.956
# stunting_2cat    -0.7912      0.287     -2.761      0.006      -1.353      -0.229
# agemonr1          0.0273      0.022      1.241      0.215      -0.016       0.071
# chsexr1          -0.8130      0.164     -4.948      0.000      -1.135      -0.491
# agegapr1         -0.0170      0.020     -0.840      0.401      -0.057       0.023
# momeduyrsr1       0.3132      0.025     12.750      0.000       0.265       0.361
# hhsizer1         -0.2777      0.046     -5.983      0.000      -0.369      -0.187
# wi_newr1          5.5144      0.523     10.542      0.000       4.488       6.541
# ==============================================================================
# Omnibus:                      109.089   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.104
# Skew:                          -0.600   Prob(JB):                     1.54e-33
# Kurtosis:                       3.973   Cond. No.                         554.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
